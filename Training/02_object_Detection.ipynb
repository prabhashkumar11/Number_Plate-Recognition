# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os 
import cv2

# %%
df=pd.read_csv('labels.csv')
df.head()
# Out:
#                     filepath  xmin  xmax  ymin  ymax
# 0    ./annotations\Cars0.xml   226   419   125   173
# 1    ./annotations\Cars1.xml   134   262   128   160
# 2   ./annotations\Cars10.xml   140   303     5   148
# 3  ./annotations\Cars100.xml   175   214   114   131
# 4  ./annotations\Cars101.xml   167   240   202   220

# %%
import xml.etree.ElementTree as xet

# %%
filename=df['filepath'][0]

# %%
def getFileName(filename):
    filename_image=xet.parse(filename).getroot().find('filename').text
    filepath_image=os.path.join('./images',filename_image)
    return filepath_image

# %%
getFileName(filename)
# Out:
# './images\\Cars0.png'

# %%
image_path=list(df['filepath'].apply(getFileName))
image_path
# Out:
# ['./images\\Cars0.png',
#  './images\\Cars1.png',
#  './images\\Cars10.png',
#  './images\\Cars100.png',
#  './images\\Cars101.png',
#  './images\\Cars102.png',
#  './images\\Cars103.png',
#  './images\\Cars104.png',
#  './images\\Cars105.png',
#  './images\\Cars106.png',
#  './images\\Cars107.png',
#  './images\\Cars108.png',
#  './images\\Cars109.png',
#  './images\\Cars11.png',
#  './images\\Cars110.png',
#  './images\\Cars111.png',
#  './images\\Cars112.png',
#  './images\\Cars113.png',
#  './images\\Cars114.png',
#  './images\\Cars115.png',
#  './images\\Cars116.png',
#  './images\\Cars117.png',
#  './images\\Cars118.png',
#  './images\\Cars119.png',
#  './images\\Cars12.png',
#  './images\\Cars120.png',
#  './images\\Cars121.png',
#  './images\\Cars122.png',
#  './images\\Cars123.png',
#  './images\\Cars124.png',
#  './images\\Cars125.png',
#  './images\\Cars126.png',
#  './images\\Cars127.png',
#  './images\\Cars128.png',
#  './images\\Cars129.png',
#  './images\\Cars13.png',
#  './images\\Cars130.png',
#  './images\\Cars131.png',
#  './images\\Cars132.png',
#  './images\\Cars133.png',
#  './images\\Cars134.png',
#  './images\\Cars135.png',
#  './images\\Cars136.png',
#  './images\\Cars137.png',
#  './images\\Cars138.png',
#  './images\\Cars139.png',
#  './images\\Cars14.png',
#  './images\\Cars140.png',
#  './images\\Cars141.png',
#  './images\\Cars142.png',
#  './images\\Cars143.png',
#  './images\\Cars144.png',
#  './images\\Cars145.png',
#  './images\\Cars146.png',
#  './images\\Cars147.png',
#  './images\\Cars148.png',
#  './images\\Cars149.png',
#  './images\\Cars15.png',
#  './images\\Cars150.png',
#  './images\\Cars151.png',
#  './images\\Cars152.png',
#  './images\\Cars153.png',
#  './images\\Cars154.png',
#  './images\\Cars155.png',
#  './images\\Cars156.png',
#  './images\\Cars157.png',
#  './images\\Cars158.png',
#  './images\\Cars159.png',
#  './images\\Cars16.png',
#  './images\\Cars160.png',
#  './images\\Cars161.png',
#  './images\\Cars162.png',
#  './images\\Cars163.png',
#  './images\\Cars164.png',
#  './images\\Cars165.png',
#  './images\\Cars166.png',
#  './images\\Cars167.png',
#  './images\\Cars168.png',
#  './images\\Cars169.png',
#  './images\\Cars17.png',
#  './images\\Cars170.png',
#  './images\\Cars171.png',
#  './images\\Cars172.png',
#  './images\\Cars173.png',
#  './images\\Cars174.png',
#  './images\\Cars175.png',
#  './images\\Cars176.png',
#  './images\\Cars177.png',
#  './images\\Cars178.png',
#  './images\\Cars179.png',
#  './images\\Cars18.png',
#  './images\\Cars180.png',
#  './images\\Cars181.png',
#  './images\\Cars182.png',
#  './images\\Cars183.png',
#  './images\\Cars184.png',
#  './images\\Cars185.png',
#  './images\\Cars186.png',
#  './images\\Cars187.png',
#  './images\\Cars188.png',
#  './images\\Cars189.png',
#  './images\\Cars19.png',
#  './images\\Cars190.png',
#  './images\\Cars191.png',
#  './images\\Cars192.png',
#  './images\\Cars193.png',
#  './images\\Cars194.png',
#  './images\\Cars195.png',
#  './images\\Cars196.png',
#  './images\\Cars197.png',
#  './images\\Cars198.png',
#  './images\\Cars199.png',
#  './images\\Cars2.png',
#  './images\\Cars20.png',
#  './images\\Cars200.png',
#  './images\\Cars201.png',
#  './images\\Cars202.png',
#  './images\\Cars203.png',
#  './images\\Cars204.png',
#  './images\\Cars205.png',
#  './images\\Cars206.png',
#  './images\\Cars207.png',
#  './images\\Cars208.png',
#  './images\\Cars209.png',
#  './images\\Cars21.png',
#  './images\\Cars210.png',
#  './images\\Cars211.png',
#  './images\\Cars212.png',
#  './images\\Cars213.png',
#  './images\\Cars214.png',
#  './images\\Cars215.png',
#  './images\\Cars216.png',
#  './images\\Cars217.png',
#  './images\\Cars218.png',
#  './images\\Cars219.png',
#  './images\\Cars22.png',
#  './images\\Cars220.png',
#  './images\\Cars221.png',
#  './images\\Cars222.png',
#  './images\\Cars223.png',
#  './images\\Cars224.png',
#  './images\\Cars225.png',
#  './images\\Cars226.png',
#  './images\\Cars227.png',
#  './images\\Cars228.png',
#  './images\\Cars229.png',
#  './images\\Cars23.png',
#  './images\\Cars230.png',
#  './images\\Cars231.png',
#  './images\\Cars232.png',
#  './images\\Cars233.png',
#  './images\\Cars234.png',
#  './images\\Cars235.png',
#  './images\\Cars236.png',
#  './images\\Cars237.png',
#  './images\\Cars238.png',
#  './images\\Cars239.png',
#  './images\\Cars24.png',
#  './images\\Cars240.png',
#  './images\\Cars241.png',
#  './images\\Cars242.png',
#  './images\\Cars243.png',
#  './images\\Cars244.png',
#  './images\\Cars245.png',
#  './images\\Cars246.png',
#  './images\\Cars247.png',
#  './images\\Cars248.png',
#  './images\\Cars249.png',
#  './images\\Cars25.png',
#  './images\\Cars250.png',
#  './images\\Cars251.png',
#  './images\\Cars252.png',
#  './images\\Cars253.png',
#  './images\\Cars254.png',
#  './images\\Cars255.png',
#  './images\\Cars256.png',
#  './images\\Cars257.png',
#  './images\\Cars258.png',
#  './images\\Cars259.png',
#  './images\\Cars26.png',
#  './images\\Cars260.png',
#  './images\\Cars261.png',
#  './images\\Cars262.png',
#  './images\\Cars263.png',
#  './images\\Cars264.png',
#  './images\\Cars265.png',
#  './images\\Cars266.png',
#  './images\\Cars267.png',
#  './images\\Cars268.png',
#  './images\\Cars269.png',
#  './images\\Cars27.png',
#  './images\\Cars270.png',
#  './images\\Cars271.png',
#  './images\\Cars272.png',
#  './images\\Cars273.png',
#  './images\\Cars274.png',
#  './images\\Cars275.png',
#  './images\\Cars276.png',
#  './images\\Cars277.png',
#  './images\\Cars278.png',
#  './images\\Cars279.png',
#  './images\\Cars28.png',
#  './images\\Cars280.png',
#  './images\\Cars281.png',
#  './images\\Cars282.png',
#  './images\\Cars283.png',
#  './images\\Cars284.png',
#  './images\\Cars285.png',
#  './images\\Cars286.png',
#  './images\\Cars287.png',
#  './images\\Cars288.png',
#  './images\\Cars289.png',
#  './images\\Cars29.png',
#  './images\\Cars290.png',
#  './images\\Cars291.png',
#  './images\\Cars292.png',
#  './images\\Cars293.png',
#  './images\\Cars294.png',
#  './images\\Cars295.png',
#  './images\\Cars296.png',
#  './images\\Cars297.png',
#  './images\\Cars298.png',
#  './images\\Cars299.png',
#  './images\\Cars3.png',
#  './images\\Cars30.png',
#  './images\\Cars300.png',
#  './images\\Cars301.png',
#  './images\\Cars302.png',
#  './images\\Cars303.png',
#  './images\\Cars304.png',
#  './images\\Cars305.png',
#  './images\\Cars306.png',
#  './images\\Cars307.png',
#  './images\\Cars308.png',
#  './images\\Cars309.png',
#  './images\\Cars31.png',
#  './images\\Cars310.png',
#  './images\\Cars311.png',
#  './images\\Cars312.png',
#  './images\\Cars313.png',
#  './images\\Cars314.png',
#  './images\\Cars315.png',
#  './images\\Cars316.png',
#  './images\\Cars317.png',
#  './images\\Cars318.png',
#  './images\\Cars319.png',
#  './images\\Cars32.png',
#  './images\\Cars320.png',
#  './images\\Cars321.png',
#  './images\\Cars322.png',
#  './images\\Cars323.png',
#  './images\\Cars324.png',
#  './images\\Cars325.png',
#  './images\\Cars326.png',
#  './images\\Cars327.png',
#  './images\\Cars328.png',
#  './images\\Cars329.png',
#  './images\\Cars33.png',
#  './images\\Cars330.png',
#  './images\\Cars331.png',
#  './images\\Cars332.png',
#  './images\\Cars333.png',
#  './images\\Cars334.png',
#  './images\\Cars335.png',
#  './images\\Cars336.png',
#  './images\\Cars337.png',
#  './images\\Cars338.png',
#  './images\\Cars339.png',
#  './images\\Cars34.png',
#  './images\\Cars340.png',
#  './images\\Cars341.png',
#  './images\\Cars342.png',
#  './images\\Cars343.png',
#  './images\\Cars344.png',
#  './images\\Cars345.png',
#  './images\\Cars346.png',
#  './images\\Cars347.png',
#  './images\\Cars348.png',
#  './images\\Cars349.png',
#  './images\\Cars35.png',
#  './images\\Cars350.png',
#  './images\\Cars351.png',
#  './images\\Cars352.png',
#  './images\\Cars353.png',
#  './images\\Cars354.png',
#  './images\\Cars355.png',
#  './images\\Cars356.png',
#  './images\\Cars357.png',
#  './images\\Cars358.png',
#  './images\\Cars359.png',
#  './images\\Cars36.png',
#  './images\\Cars360.png',
#  './images\\Cars361.png',
#  './images\\Cars362.png',
#  './images\\Cars363.png',
#  './images\\Cars364.png',
#  './images\\Cars365.png',
#  './images\\Cars366.png',
#  './images\\Cars367.png',
#  './images\\Cars368.png',
#  './images\\Cars369.png',
#  './images\\Cars37.png',
#  './images\\Cars370.png',
#  './images\\Cars371.png',
#  './images\\Cars372.png',
#  './images\\Cars373.png',
#  './images\\Cars374.png',
#  './images\\Cars375.png',
#  './images\\Cars376.png',
#  './images\\Cars377.png',
#  './images\\Cars378.png',
#  './images\\Cars379.png',
#  './images\\Cars38.png',
#  './images\\Cars380.png',
#  './images\\Cars381.png',
#  './images\\Cars382.png',
#  './images\\Cars383.png',
#  './images\\Cars384.png',
#  './images\\Cars385.png',
#  './images\\Cars386.png',
#  './images\\Cars387.png',
#  './images\\Cars388.png',
#  './images\\Cars389.png',
#  './images\\Cars39.png',
#  './images\\Cars390.png',
#  './images\\Cars391.png',
#  './images\\Cars392.png',
#  './images\\Cars393.png',
#  './images\\Cars394.png',
#  './images\\Cars395.png',
#  './images\\Cars396.png',
#  './images\\Cars397.png',
#  './images\\Cars398.png',
#  './images\\Cars399.png',
#  './images\\Cars4.png',
#  './images\\Cars40.png',
#  './images\\Cars400.png',
#  './images\\Cars401.png',
#  './images\\Cars402.png',
#  './images\\Cars403.png',
#  './images\\Cars404.png',
#  './images\\Cars405.png',
#  './images\\Cars406.png',
#  './images\\Cars407.png',
#  './images\\Cars408.png',
#  './images\\Cars409.png',
#  './images\\Cars41.png',
#  './images\\Cars410.png',
#  './images\\Cars411.png',
#  './images\\Cars412.png',
#  './images\\Cars413.png',
#  './images\\Cars414.png',
#  './images\\Cars415.png',
#  './images\\Cars416.png',
#  './images\\Cars417.png',
#  './images\\Cars418.png',
#  './images\\Cars419.png',
#  './images\\Cars42.png',
#  './images\\Cars420.png',
#  './images\\Cars421.png',
#  './images\\Cars422.png',
#  './images\\Cars423.png',
#  './images\\Cars424.png',
#  './images\\Cars425.png',
#  './images\\Cars426.png',
#  './images\\Cars427.png',
#  './images\\Cars428.png',
#  './images\\Cars429.png',
#  './images\\Cars43.png',
#  './images\\Cars430.png',
#  './images\\Cars431.png',
#  './images\\Cars432.png',
#  './images\\Cars44.png',
#  './images\\Cars45.png',
#  './images\\Cars46.png',
#  './images\\Cars47.png',
#  './images\\Cars48.png',
#  './images\\Cars49.png',
#  './images\\Cars5.png',
#  './images\\Cars50.png',
#  './images\\Cars51.png',
#  './images\\Cars52.png',
#  './images\\Cars53.png',
#  './images\\Cars54.png',
#  './images\\Cars55.png',
#  './images\\Cars56.png',
#  './images\\Cars57.png',
#  './images\\Cars58.png',
#  './images\\Cars59.png',
#  './images\\Cars6.png',
#  './images\\Cars60.png',
#  './images\\Cars61.png',
#  './images\\Cars62.png',
#  './images\\Cars63.png',
#  './images\\Cars64.png',
#  './images\\Cars65.png',
#  './images\\Cars66.png',
#  './images\\Cars67.png',
#  './images\\Cars68.png',
#  './images\\Cars69.png',
#  './images\\Cars7.png',
#  './images\\Cars70.png',
#  './images\\Cars71.png',
#  './images\\Cars72.png',
#  './images\\Cars73.png',
#  './images\\Cars74.png',
#  './images\\Cars75.png',
#  './images\\Cars76.png',
#  './images\\Cars77.png',
#  './images\\Cars78.png',
#  './images\\Cars79.png',
#  './images\\Cars8.png',
#  './images\\Cars80.png',
#  './images\\Cars81.png',
#  './images\\Cars82.png',
#  './images\\Cars83.png',
#  './images\\Cars84.png',
#  './images\\Cars85.png',
#  './images\\Cars86.png',
#  './images\\Cars87.png',
#  './images\\Cars88.png',
#  './images\\Cars89.png',
#  './images\\Cars9.png',
#  './images\\Cars90.png',
#  './images\\Cars91.png',
#  './images\\Cars92.png',
#  './images\\Cars93.png',
#  './images\\Cars94.png',
#  './images\\Cars95.png',
#  './images\\Cars96.png',
#  './images\\Cars97.png',
#  './images\\Cars98.png',
#  './images\\Cars99.png']

# %%
#### verify Image and Output

# %%
file_path=image_path[0]
file_path
# Out:
# './images\\Cars0.png'

# %%
img=cv2.imread(file_path)
cv2.rectangle(img,(226,125),(419,173),(0,255,9),3)
cv2.imshow('example',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#226	419	125	173
cv2.rectangle(img,(226,125),(419,173),(0,255,9),3)
# Out:
# array([[[100,  75,  25],
#         [159, 130,  73],
#         [158, 127,  52],
#         ...,
#         [ 41,  39,  38],
#         [ 36,  34,  33],
#         [ 40,  38,  37]],
#
#        [[101,  79,  31],
#         [146, 121,  65],
#         [151, 119,  46],
#         ...,
#         [ 32,  33,  31],
#         [ 42,  43,  41],
#         [ 27,  28,  26]],
#
#        [[104,  87,  44],
#         [139, 117,  65],
#         [146, 116,  43],
#         ...,
#         [ 33,  37,  32],
#         [ 36,  40,  35],
#         [ 26,  30,  25]],
#
#        ...,
#
#        [[ 41,  49,  72],
#         [ 42,  50,  73],
#         [ 43,  51,  74],
#         ...,
#         [ 48,  67, 104],
#         [ 48,  68, 103],
#         [ 48,  67, 104]],
#
#        [[ 44,  52,  75],
#         [ 45,  53,  76],
#         [ 44,  52,  75],
#         ...,
#         [ 47,  66, 104],
#         [ 48,  67, 104],
#         [ 48,  67, 105]],
#
#        [[ 44,  52,  75],
#         [ 44,  52,  75],
#         [ 44,  52,  75],
#         ...,
#         [ 45,  64, 102],
#         [ 46,  65, 103],
#         [ 47,  66, 104]]], dtype=uint8)

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
labels=df.iloc[:,1:].values

# %%
len(image_path)
# Out:
# 433

# %%
data=[]
output=[]
for ind in range(len(image_path)):
    image=image_path[ind]
    img_arr=cv2.imread(image)
    h,w,d=img_arr.shape
    #prepprocessing
    load_image=load_img(image,target_size=(224,224))
    load_image_arr=img_to_array(load_image)
    norm_load_image_arr=load_image_arr/255.0 #normalization
    #normalization to labels
    xmin,xmax,ymin,ymax=labels[ind]
    nxmin,nxmax=xmin/w,xmax/w
    nymin,nymax=ymin/h,ymax/h
    label_norm=(nxmin,nxmax,nymin,nymax)
    #_________appen
    data.append(norm_load_image_arr)
    output.append(label_norm)

# %%
label_norm
# Out:
# (0.452, 0.838, 0.4664179104477612, 0.6455223880597015)

# %%
norm_load_image_arr
# Out:
# array([[[0.28627452, 0.50980395, 0.62352943],
#         [0.17254902, 0.4862745 , 0.62352943],
#         [0.3137255 , 0.58431375, 0.7137255 ],
#         ...,
#         [0.16470589, 0.17254902, 0.16078432],
#         [0.16078432, 0.16470589, 0.17254902],
#         [0.12941177, 0.13333334, 0.14117648]],
#
#        [[0.25490198, 0.4745098 , 0.57254905],
#         [0.16078432, 0.4745098 , 0.6117647 ],
#         [0.19607843, 0.46666667, 0.5882353 ],
#         ...,
#         [0.17254902, 0.18039216, 0.1764706 ],
#         [0.15686275, 0.16470589, 0.16078432],
#         [0.16078432, 0.16862746, 0.16470589]],
#
#        [[0.25490198, 0.45882353, 0.54509807],
#         [0.15686275, 0.47058824, 0.6       ],
#         [0.21960784, 0.48235294, 0.59607846],
#         ...,
#         [0.1764706 , 0.1764706 , 0.18431373],
#         [0.19215687, 0.21176471, 0.19607843],
#         [0.13725491, 0.15686275, 0.14117648]],
#
#        ...,
#
#        [[0.28627452, 0.19607843, 0.16470589],
#         [0.28627452, 0.19607843, 0.16470589],
#         [0.28627452, 0.19607843, 0.16470589],
#         ...,
#         [0.39215687, 0.24705882, 0.17254902],
#         [0.4       , 0.2627451 , 0.18431373],
#         [0.40392157, 0.26666668, 0.1882353 ]],
#
#        [[0.29803923, 0.20784314, 0.1764706 ],
#         [0.2901961 , 0.2       , 0.16862746],
#         [0.28235295, 0.19215687, 0.16078432],
#         ...,
#         [0.3882353 , 0.23921569, 0.16470589],
#         [0.40392157, 0.25882354, 0.18431373],
#         [0.40784314, 0.2627451 , 0.1882353 ]],
#
#        [[0.29411766, 0.20392157, 0.17254902],
#         [0.28235295, 0.19215687, 0.16078432],
#         [0.27450982, 0.18431373, 0.15294118],
#         ...,
#         [0.4       , 0.2509804 , 0.1764706 ],
#         [0.4       , 0.2509804 , 0.1764706 ],
#         [0.40392157, 0.25490198, 0.18039216]]], dtype=float32)

# %%
X=np.array(data,dtype=np.float32)
y=np.array(output,dtype=np.float32)

# %%
X.shape,y.shape
# Out:
# ((433, 224, 224, 3), (433, 4))

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((346, 224, 224, 3), (87, 224, 224, 3), (346, 4), (87, 4))

# %% [markdown]
# # Deep Learning Model

# %%
from tensorflow.keras.applications import MobileNetV2, InceptionV3, InceptionResNetV2
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
inception_resnet=InceptionResNetV2(weights="imagenet",include_top=False,input_tensor=Input(shape=(224,224,3)))

inception_resnet.trainable=False

headmodel=inception_resnet.output
headmodel=Flatten()(headmodel)
headmodel=Dense(500,activation='relu')(headmodel)
headmodel=Dense(250,activation='relu')(headmodel)
headmodel=Dense(4,activation='sigmoid')(headmodel)

model=Model(inputs=inception_resnet.input,outputs=headmodel)

# %%
#compile model
model.compile(loss='mse',optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_406 (Conv2D)            (None, 111, 111, 32  864         ['input_3[0][0]']
#                                 )
#
#  batch_normalization_406 (Batch  (None, 111, 111, 32  96         ['conv2d_406[0][0]']
#  Normalization)                 )
#
#  activation_406 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_406[0][0]']
#                                 )
#
#  conv2d_407 (Conv2D)            (None, 109, 109, 32  9216        ['activation_406[0][0]']
#                                 )
#
#  batch_normalization_407 (Batch  (None, 109, 109, 32  96         ['conv2d_407[0][0]']
#  Normalization)                 )
#
#  activation_407 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_407[0][0]']
#                                 )
#
#  conv2d_408 (Conv2D)            (None, 109, 109, 64  18432       ['activation_407[0][0]']
#                                 )
#
#  batch_normalization_408 (Batch  (None, 109, 109, 64  192        ['conv2d_408[0][0]']
#  Normalization)                 )
#
#  activation_408 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_408[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 54, 54, 64)  0           ['activation_408[0][0]']
#
#  conv2d_409 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_409 (Batch  (None, 54, 54, 80)  240         ['conv2d_409[0][0]']
#  Normalization)
#
#  activation_409 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_409[0][0]']
#
#  conv2d_410 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_409[0][0]']
#
#  batch_normalization_410 (Batch  (None, 52, 52, 192)  576        ['conv2d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_410[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 192)  0          ['activation_410[0][0]']
#
#  conv2d_414 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_414 (Batch  (None, 25, 25, 64)  192         ['conv2d_414[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_414[0][0]']
#
#  conv2d_412 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_415 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_414[0][0]']
#
#  batch_normalization_412 (Batch  (None, 25, 25, 48)  144         ['conv2d_412[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 25, 25, 96)  288         ['conv2d_415[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_412[0][0]']
#
#  activation_415 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_415[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 25, 25, 192)  0          ['max_pooling2d_9[0][0]']
#  oling2D)
#
#  conv2d_411 (Conv2D)            (None, 25, 25, 96)   18432       ['max_pooling2d_9[0][0]']
#
#  conv2d_413 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_412[0][0]']
#
#  conv2d_416 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_415[0][0]']
#
#  conv2d_417 (Conv2D)            (None, 25, 25, 64)   12288       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_411 (Batch  (None, 25, 25, 96)  288         ['conv2d_411[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 25, 25, 64)  192         ['conv2d_413[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 25, 25, 96)  288         ['conv2d_416[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 25, 25, 64)  192         ['conv2d_417[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_411[0][0]']
#
#  activation_413 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_413[0][0]']
#
#  activation_416 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_416[0][0]']
#
#  activation_417 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_417[0][0]']
#
#  mixed_5b (Concatenate)         (None, 25, 25, 320)  0           ['activation_411[0][0]',
#                                                                   'activation_413[0][0]',
#                                                                   'activation_416[0][0]',
#                                                                   'activation_417[0][0]']
#
#  conv2d_421 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_421 (Batch  (None, 25, 25, 32)  96          ['conv2d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_421[0][0]']
#
#  conv2d_419 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_422 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 25, 25, 32)  96          ['conv2d_419[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 25, 25, 48)  144         ['conv2d_422[0][0]']
#  Normalization)
#
#  activation_419 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_422[0][0]']
#
#  conv2d_418 (Conv2D)            (None, 25, 25, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_420 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_419[0][0]']
#
#  conv2d_423 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 25, 25, 32)  96          ['conv2d_418[0][0]']
#  Normalization)
#
#  batch_normalization_420 (Batch  (None, 25, 25, 32)  96          ['conv2d_420[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 25, 25, 64)  192         ['conv2d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_418[0][0]']
#
#  activation_420 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_423[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_418[0][0]',
#                                                                   'activation_420[0][0]',
#                                                                   'activation_423[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 25, 25, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 25, 25, 320)  0           ['block35_1[0][0]']
#
#  conv2d_427 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_427 (Batch  (None, 25, 25, 32)  96          ['conv2d_427[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_427[0][0]']
#
#  conv2d_425 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_428 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_427[0][0]']
#
#  batch_normalization_425 (Batch  (None, 25, 25, 32)  96          ['conv2d_425[0][0]']
#  Normalization)
#
#  batch_normalization_428 (Batch  (None, 25, 25, 48)  144         ['conv2d_428[0][0]']
#  Normalization)
#
#  activation_425 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_425[0][0]']
#
#  activation_428 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_428[0][0]']
#
#  conv2d_424 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_426 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_425[0][0]']
#
#  conv2d_429 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_428[0][0]']
#
#  batch_normalization_424 (Batch  (None, 25, 25, 32)  96          ['conv2d_424[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 25, 25, 32)  96          ['conv2d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 25, 25, 64)  192         ['conv2d_429[0][0]']
#  Normalization)
#
#  activation_424 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_424[0][0]']
#
#  activation_426 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_429[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_424[0][0]',
#                                                                   'activation_426[0][0]',
#                                                                   'activation_429[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 25, 25, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 25, 25, 320)  0           ['block35_2[0][0]']
#
#  conv2d_433 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_433 (Batch  (None, 25, 25, 32)  96          ['conv2d_433[0][0]']
#  Normalization)
#
#  activation_433 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_433[0][0]']
#
#  conv2d_431 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_434 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_433[0][0]']
#
#  batch_normalization_431 (Batch  (None, 25, 25, 32)  96          ['conv2d_431[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 25, 25, 48)  144         ['conv2d_434[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_434[0][0]']
#
#  conv2d_430 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_432 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_431[0][0]']
#
#  conv2d_435 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_434[0][0]']
#
#  batch_normalization_430 (Batch  (None, 25, 25, 32)  96          ['conv2d_430[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 25, 25, 32)  96          ['conv2d_432[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 25, 25, 64)  192         ['conv2d_435[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_430[0][0]']
#
#  activation_432 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_432[0][0]']
#
#  activation_435 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_435[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_430[0][0]',
#                                                                   'activation_432[0][0]',
#                                                                   'activation_435[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 25, 25, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 25, 25, 320)  0           ['block35_3[0][0]']
#
#  conv2d_439 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_439 (Batch  (None, 25, 25, 32)  96          ['conv2d_439[0][0]']
#  Normalization)
#
#  activation_439 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_439[0][0]']
#
#  conv2d_437 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_440 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_439[0][0]']
#
#  batch_normalization_437 (Batch  (None, 25, 25, 32)  96          ['conv2d_437[0][0]']
#  Normalization)
#
#  batch_normalization_440 (Batch  (None, 25, 25, 48)  144         ['conv2d_440[0][0]']
#  Normalization)
#
#  activation_437 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_437[0][0]']
#
#  activation_440 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_440[0][0]']
#
#  conv2d_436 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_438 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_437[0][0]']
#
#  conv2d_441 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_440[0][0]']
#
#  batch_normalization_436 (Batch  (None, 25, 25, 32)  96          ['conv2d_436[0][0]']
#  Normalization)
#
#  batch_normalization_438 (Batch  (None, 25, 25, 32)  96          ['conv2d_438[0][0]']
#  Normalization)
#
#  batch_normalization_441 (Batch  (None, 25, 25, 64)  192         ['conv2d_441[0][0]']
#  Normalization)
#
#  activation_436 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_436[0][0]']
#
#  activation_438 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_438[0][0]']
#
#  activation_441 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_441[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_436[0][0]',
#                                                                   'activation_438[0][0]',
#                                                                   'activation_441[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 25, 25, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 25, 25, 320)  0           ['block35_4[0][0]']
#
#  conv2d_445 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_445 (Batch  (None, 25, 25, 32)  96          ['conv2d_445[0][0]']
#  Normalization)
#
#  activation_445 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_445[0][0]']
#
#  conv2d_443 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_446 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_445[0][0]']
#
#  batch_normalization_443 (Batch  (None, 25, 25, 32)  96          ['conv2d_443[0][0]']
#  Normalization)
#
#  batch_normalization_446 (Batch  (None, 25, 25, 48)  144         ['conv2d_446[0][0]']
#  Normalization)
#
#  activation_443 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_443[0][0]']
#
#  activation_446 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_446[0][0]']
#
#  conv2d_442 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_444 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_443[0][0]']
#
#  conv2d_447 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_446[0][0]']
#
#  batch_normalization_442 (Batch  (None, 25, 25, 32)  96          ['conv2d_442[0][0]']
#  Normalization)
#
#  batch_normalization_444 (Batch  (None, 25, 25, 32)  96          ['conv2d_444[0][0]']
#  Normalization)
#
#  batch_normalization_447 (Batch  (None, 25, 25, 64)  192         ['conv2d_447[0][0]']
#  Normalization)
#
#  activation_442 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_442[0][0]']
#
#  activation_444 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_444[0][0]']
#
#  activation_447 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_447[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_442[0][0]',
#                                                                   'activation_444[0][0]',
#                                                                   'activation_447[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 25, 25, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 25, 25, 320)  0           ['block35_5[0][0]']
#
#  conv2d_451 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_451 (Batch  (None, 25, 25, 32)  96          ['conv2d_451[0][0]']
#  Normalization)
#
#  activation_451 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_451[0][0]']
#
#  conv2d_449 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_452 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_451[0][0]']
#
#  batch_normalization_449 (Batch  (None, 25, 25, 32)  96          ['conv2d_449[0][0]']
#  Normalization)
#
#  batch_normalization_452 (Batch  (None, 25, 25, 48)  144         ['conv2d_452[0][0]']
#  Normalization)
#
#  activation_449 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_449[0][0]']
#
#  activation_452 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_452[0][0]']
#
#  conv2d_448 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_450 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_449[0][0]']
#
#  conv2d_453 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_452[0][0]']
#
#  batch_normalization_448 (Batch  (None, 25, 25, 32)  96          ['conv2d_448[0][0]']
#  Normalization)
#
#  batch_normalization_450 (Batch  (None, 25, 25, 32)  96          ['conv2d_450[0][0]']
#  Normalization)
#
#  batch_normalization_453 (Batch  (None, 25, 25, 64)  192         ['conv2d_453[0][0]']
#  Normalization)
#
#  activation_448 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_448[0][0]']
#
#  activation_450 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_450[0][0]']
#
#  activation_453 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_453[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_448[0][0]',
#                                                                   'activation_450[0][0]',
#                                                                   'activation_453[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 25, 25, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 25, 25, 320)  0           ['block35_6[0][0]']
#
#  conv2d_457 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_457 (Batch  (None, 25, 25, 32)  96          ['conv2d_457[0][0]']
#  Normalization)
#
#  activation_457 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_457[0][0]']
#
#  conv2d_455 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_458 (Conv2D)            (None, 25, 25, 48)   13824       ['activation_457[0][0]']
#
#  batch_normalization_455 (Batch  (None, 25, 25, 32)  96          ['conv2d_455[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 25, 25, 48)  144         ['conv2d_458[0][0]']
#  Normalization)
#
#  activation_455 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_458[0][0]']
#
#  conv2d_454 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_456 (Conv2D)            (None, 25, 25, 32)   9216        ['activation_455[0][0]']
#
#  conv2d_459 (Conv2D)            (None, 25, 25, 64)   27648       ['activation_458[0][0]']
#
#  batch_normalization_454 (Batch  (None, 25, 25, 32)  96          ['conv2d_454[0][0]']
#  Normalization)
#
#  batch_normalization_456 (Batch  (None, 25, 25, 32)  96          ['conv2d_456[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 25, 25, 64)  192         ['conv2d_459[0][0]']
#  Normalization)
#
#  activation_454 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_454[0][0]']
#
#  activation_456 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_456[0][0]']
#
#  activation_459 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_459[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 25, 25, 128)  0           ['activation_454[0][0]',
#                                                                   'activation_456[0][0]',
#                                                                   'activation_459[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 25, 25, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 25, 25, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 25, 25, 320)  0           ['block35_7[0][0]']
#
#  conv2d_463 (Conv2D)            (None, 25, 25, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_463 (Batch  (None, 25, 25, 32)  96          ['conv2d_463[0][0]']
#  Normalization)
#
# ...
#  conv2d_595 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_594[0][0]']
#
#  batch_normalization_595 (Batch  (None, 5, 5, 224)   672         ['conv2d_595[0][0]']
#  Normalization)
#
#  activation_595 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_595[0][0]']
#
#  conv2d_593 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_596 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_595[0][0]']
#
#  batch_normalization_593 (Batch  (None, 5, 5, 192)   576         ['conv2d_593[0][0]']
#  Normalization)
#
#  batch_normalization_596 (Batch  (None, 5, 5, 256)   768         ['conv2d_596[0][0]']
#  Normalization)
#
#  activation_593 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_593[0][0]']
#
#  activation_596 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_596[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_593[0][0]',
#                                                                   'activation_596[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 5, 5, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_598 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_598 (Batch  (None, 5, 5, 192)   576         ['conv2d_598[0][0]']
#  Normalization)
#
#  activation_598 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_598[0][0]']
#
#  conv2d_599 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_598[0][0]']
#
#  batch_normalization_599 (Batch  (None, 5, 5, 224)   672         ['conv2d_599[0][0]']
#  Normalization)
#
#  activation_599 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_599[0][0]']
#
#  conv2d_597 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_600 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_599[0][0]']
#
#  batch_normalization_597 (Batch  (None, 5, 5, 192)   576         ['conv2d_597[0][0]']
#  Normalization)
#
#  batch_normalization_600 (Batch  (None, 5, 5, 256)   768         ['conv2d_600[0][0]']
#  Normalization)
#
#  activation_597 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_597[0][0]']
#
#  activation_600 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_600[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_597[0][0]',
#                                                                   'activation_600[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 5, 5, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_602 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_602 (Batch  (None, 5, 5, 192)   576         ['conv2d_602[0][0]']
#  Normalization)
#
#  activation_602 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_602[0][0]']
#
#  conv2d_603 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_602[0][0]']
#
#  batch_normalization_603 (Batch  (None, 5, 5, 224)   672         ['conv2d_603[0][0]']
#  Normalization)
#
#  activation_603 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_603[0][0]']
#
#  conv2d_601 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_604 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_603[0][0]']
#
#  batch_normalization_601 (Batch  (None, 5, 5, 192)   576         ['conv2d_601[0][0]']
#  Normalization)
#
#  batch_normalization_604 (Batch  (None, 5, 5, 256)   768         ['conv2d_604[0][0]']
#  Normalization)
#
#  activation_601 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_601[0][0]']
#
#  activation_604 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_604[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 5, 5, 448)    0           ['activation_601[0][0]',
#                                                                   'activation_604[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 5, 5, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 5, 5, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 5, 5, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_606 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_606 (Batch  (None, 5, 5, 192)   576         ['conv2d_606[0][0]']
#  Normalization)
#
#  activation_606 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_606[0][0]']
#
#  conv2d_607 (Conv2D)            (None, 5, 5, 224)    129024      ['activation_606[0][0]']
#
#  batch_normalization_607 (Batch  (None, 5, 5, 224)   672         ['conv2d_607[0][0]']
#  Normalization)
#
#  activation_607 (Activation)    (None, 5, 5, 224)    0           ['batch_normalization_607[0][0]']
#
#  conv2d_605 (Conv2D)            (None, 5, 5, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_608 (Conv2D)            (None, 5, 5, 256)    172032      ['activation_607[0][0]']
#
#  batch_normalization_605 (Batch  (None, 5, 5, 192)   576         ['conv2d_605[0][0]']
#  Normalization)
#
#  batch_normalization_608 (Batch  (None, 5, 5, 256)   768         ['conv2d_608[0][0]']
#  Normalization)
#
#  activation_605 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_605[0][0]']
#
#  activation_608 (Activation)    (None, 5, 5, 256)    0           ['batch_normalization_608[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 5, 5, 448)    0           ['activation_605[0][0]',
#                                                                   'activation_608[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 5, 5, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 5, 5, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 5, 5, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 5, 5, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 5, 5, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_1 (Flatten)            (None, 38400)        0           ['conv_7b_ac[0][0]']
#
#  dense_3 (Dense)                (None, 500)          19200500    ['flatten_1[0][0]']
#
#  dense_4 (Dense)                (None, 250)          125250      ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 4)            1004        ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 73,663,490
# Trainable params: 19,326,754
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %% [markdown]
# # model training

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
tfb=TensorBoard('object_detection')

# %%
history=model.fit(x=x_train,y=y_train,batch_size=10,epochs=100,
                 validation_data=(x_test,y_test),callbacks=[tfb])
# Out:
# Epoch 1/100
# 35/35 [==============================] - 103s 3s/step - loss: 0.1285 - val_loss: 0.1467
# Epoch 2/100
# 35/35 [==============================] - 60s 2s/step - loss: 0.1310 - val_loss: 0.1316
# Epoch 3/100
# 35/35 [==============================] - 61s 2s/step - loss: 0.1283 - val_loss: 0.1348
# Epoch 4/100
# 35/35 [==============================] - 68s 2s/step - loss: 0.1253 - val_loss: 0.1234
# Epoch 5/100
# 35/35 [==============================] - 72s 2s/step - loss: 0.1236 - val_loss: 0.1240
# Epoch 6/100
# 35/35 [==============================] - 69s 2s/step - loss: 0.1227 - val_loss: 0.1334
# Epoch 7/100
# 35/35 [==============================] - 73s 2s/step - loss: 0.1231 - val_loss: 0.1218
# Epoch 8/100
# 35/35 [==============================] - 72s 2s/step - loss: 0.1203 - val_loss: 0.1223
# Epoch 9/100
# 35/35 [==============================] - 76s 2s/step - loss: 0.1196 - val_loss: 0.1213
# Epoch 10/100
# 35/35 [==============================] - 75s 2s/step - loss: 0.1200 - val_loss: 0.1213
# Epoch 11/100
# 35/35 [==============================] - 72s 2s/step - loss: 0.1197 - val_loss: 0.1207
# Epoch 12/100
# 35/35 [==============================] - 56s 2s/step - loss: 0.1192 - val_loss: 0.1205
# Epoch 13/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.1192 - val_loss: 0.1206
# Epoch 14/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.1191 - val_loss: 0.1213
# Epoch 15/100
# 35/35 [==============================] - 52s 2s/step - loss: 0.1186 - val_loss: 0.1206
# Epoch 16/100
# 35/35 [==============================] - 51s 1s/step - loss: 0.1184 - val_loss: 0.1210
# Epoch 17/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.1187 - val_loss: 0.1210
# Epoch 18/100
# 35/35 [==============================] - 52s 2s/step - loss: 0.1186 - val_loss: 0.1207
# Epoch 19/100
# 35/35 [==============================] - 49s 1s/step - loss: 0.1183 - val_loss: 0.1203
# Epoch 20/100
# 35/35 [==============================] - 52s 1s/step - loss: 0.1180 - val_loss: 0.1203
# Epoch 21/100
# 35/35 [==============================] - 53s 2s/step - loss: 0.1181 - val_loss: 0.1203
# Epoch 22/100
# 35/35 [==============================] - 65s 2s/step - loss: 0.1180 - val_loss: 0.1208
# Epoch 23/100
# 35/35 [==============================] - 72s 2s/step - loss: 0.1184 - val_loss: 0.1204
# Epoch 24/100
# 35/35 [==============================] - 67s 2s/step - loss: 0.1182 - val_loss: 0.1204
# Epoch 25/100
# 35/35 [==============================] - 73s 2s/step - loss: 0.1184 - val_loss: 0.1206
# Epoch 26/100
# 35/35 [==============================] - 78s 2s/step - loss: 0.1182 - val_loss: 0.1211
# Epoch 27/100
# 35/35 [==============================] - 69s 2s/step - loss: 0.1186 - val_loss: 0.1204
# Epoch 28/100
# 35/35 [==============================] - 75s 2s/step - loss: 0.1191 - val_loss: 0.1205
# Epoch 29/100
# 35/35 [==============================] - 69s 2s/step - loss: 0.1188 - val_loss: 0.1204
# Epoch 30/100
# 35/35 [==============================] - 55s 2s/step - loss: 0.1182 - val_loss: 0.1204
# Epoch 31/100
# 35/35 [==============================] - 67s 2s/step - loss: 0.1179 - val_loss: 0.1204
# Epoch 32/100
# 35/35 [==============================] - 64s 2s/step - loss: 0.1179 - val_loss: 0.1201
# Epoch 33/100
# 35/35 [==============================] - 68s 2s/step - loss: 0.1178 - val_loss: 0.1202
# Epoch 34/100
# 35/35 [==============================] - 75s 2s/step - loss: 0.1182 - val_loss: 0.1204
# Epoch 35/100
# 35/35 [==============================] - 68s 2s/step - loss: 0.1180 - val_loss: 0.1201
# Epoch 36/100
# 35/35 [==============================] - 65s 2s/step - loss: 0.1179 - val_loss: 0.1201
# Epoch 37/100
# 35/35 [==============================] - 68s 2s/step - loss: 0.1178 - val_loss: 0.1200
# Epoch 38/100
# 35/35 [==============================] - 65s 2s/step - loss: 0.1210 - val_loss: 0.1224
# Epoch 39/100
# 35/35 [==============================] - 56s 2s/step - loss: 0.1193 - val_loss: 0.1209
# Epoch 40/100
# 35/35 [==============================] - 61s 2s/step - loss: 0.1188 - val_loss: 0.1173
# Epoch 41/100
# 35/35 [==============================] - 68s 2s/step - loss: 0.1162 - val_loss: 0.1213
# Epoch 42/100
# 35/35 [==============================] - 67s 2s/step - loss: 0.1221 - val_loss: 0.1246
# Epoch 43/100
# 35/35 [==============================] - 120s 3s/step - loss: 0.1198 - val_loss: 0.1209
# Epoch 44/100
# 35/35 [==============================] - 112s 3s/step - loss: 0.1186 - val_loss: 0.1227
# Epoch 45/100
# 35/35 [==============================] - 105s 3s/step - loss: 0.1184 - val_loss: 0.1205
# Epoch 46/100
# 35/35 [==============================] - 80s 2s/step - loss: 0.1172 - val_loss: 0.1184
# Epoch 47/100
# 35/35 [==============================] - 82s 2s/step - loss: 0.1088 - val_loss: 0.1165
# Epoch 48/100
# 35/35 [==============================] - 92s 3s/step - loss: 0.0837 - val_loss: 0.0753
# Epoch 49/100
# 35/35 [==============================] - 79s 2s/step - loss: 0.0526 - val_loss: 0.0511
# Epoch 50/100
# 35/35 [==============================] - 116s 3s/step - loss: 0.0383 - val_loss: 0.0440
# Epoch 51/100
# 35/35 [==============================] - 110s 3s/step - loss: 0.0327 - val_loss: 0.0428
# Epoch 52/100
# 35/35 [==============================] - 118s 3s/step - loss: 0.0309 - val_loss: 0.0425
# Epoch 53/100
# 35/35 [==============================] - 120s 3s/step - loss: 0.0303 - val_loss: 0.0426
# Epoch 54/100
# 35/35 [==============================] - 118s 3s/step - loss: 0.0296 - val_loss: 0.0393
# Epoch 55/100
# 35/35 [==============================] - 71s 2s/step - loss: 0.0104 - val_loss: 0.0192
# Epoch 56/100
# 35/35 [==============================] - 53s 2s/step - loss: 0.0044 - val_loss: 0.0165
# Epoch 57/100
# 35/35 [==============================] - 94s 3s/step - loss: 0.0024 - val_loss: 0.0154
# Epoch 58/100
# 35/35 [==============================] - 101s 3s/step - loss: 0.0017 - val_loss: 0.0150
# Epoch 59/100
# 35/35 [==============================] - 87s 2s/step - loss: 0.0014 - val_loss: 0.0156
# Epoch 60/100
# 35/35 [==============================] - 76s 2s/step - loss: 0.0012 - val_loss: 0.0155
# Epoch 61/100
# 35/35 [==============================] - 79s 2s/step - loss: 9.7277e-04 - val_loss: 0.0153
# Epoch 62/100
# 35/35 [==============================] - 76s 2s/step - loss: 7.0697e-04 - val_loss: 0.0155
# Epoch 63/100
# 35/35 [==============================] - 77s 2s/step - loss: 7.0300e-04 - val_loss: 0.0159
# Epoch 64/100
# 35/35 [==============================] - 81s 2s/step - loss: 6.0294e-04 - val_loss: 0.0154
# Epoch 65/100
# 35/35 [==============================] - 65s 2s/step - loss: 5.5734e-04 - val_loss: 0.0159
# Epoch 66/100
# 35/35 [==============================] - 75s 2s/step - loss: 5.6853e-04 - val_loss: 0.0155
# Epoch 67/100
# 35/35 [==============================] - 74s 2s/step - loss: 6.0435e-04 - val_loss: 0.0159
# Epoch 68/100
# 35/35 [==============================] - 77s 2s/step - loss: 5.4836e-04 - val_loss: 0.0153
# Epoch 69/100
# 35/35 [==============================] - 75s 2s/step - loss: 5.3229e-04 - val_loss: 0.0154
# Epoch 70/100
# 35/35 [==============================] - 70s 2s/step - loss: 6.3607e-04 - val_loss: 0.0161
# Epoch 71/100
# 35/35 [==============================] - 75s 2s/step - loss: 8.3841e-04 - val_loss: 0.0150
# Epoch 72/100
# 35/35 [==============================] - 75s 2s/step - loss: 8.0473e-04 - val_loss: 0.0159
# Epoch 73/100
# 35/35 [==============================] - 66s 2s/step - loss: 7.3690e-04 - val_loss: 0.0156
# Epoch 74/100
# 35/35 [==============================] - 63s 2s/step - loss: 5.7382e-04 - val_loss: 0.0162
# Epoch 75/100
# 35/35 [==============================] - 68s 2s/step - loss: 5.3682e-04 - val_loss: 0.0157
# Epoch 76/100
# 35/35 [==============================] - 68s 2s/step - loss: 7.0385e-04 - val_loss: 0.0158
# Epoch 77/100
# 35/35 [==============================] - 79s 2s/step - loss: 5.4532e-04 - val_loss: 0.0158
# Epoch 78/100
# 35/35 [==============================] - 73s 2s/step - loss: 5.9486e-04 - val_loss: 0.0161
# Epoch 79/100
# 35/35 [==============================] - 68s 2s/step - loss: 5.7967e-04 - val_loss: 0.0164
# Epoch 80/100
# 35/35 [==============================] - 73s 2s/step - loss: 6.8030e-04 - val_loss: 0.0164
# Epoch 81/100
# 35/35 [==============================] - 53s 2s/step - loss: 6.9335e-04 - val_loss: 0.0160
# Epoch 82/100
# 35/35 [==============================] - 51s 1s/step - loss: 5.0744e-04 - val_loss: 0.0160
# Epoch 83/100
# 35/35 [==============================] - 51s 1s/step - loss: 4.4511e-04 - val_loss: 0.0162
# Epoch 84/100
# 35/35 [==============================] - 63s 2s/step - loss: 4.7937e-04 - val_loss: 0.0156
# Epoch 85/100
# 35/35 [==============================] - 79s 2s/step - loss: 4.1863e-04 - val_loss: 0.0162
# Epoch 86/100
# 35/35 [==============================] - 77s 2s/step - loss: 3.5931e-04 - val_loss: 0.0158
# Epoch 87/100
# 35/35 [==============================] - 81s 2s/step - loss: 4.0651e-04 - val_loss: 0.0159
# Epoch 88/100
# 35/35 [==============================] - 73s 2s/step - loss: 4.1006e-04 - val_loss: 0.0158
# Epoch 89/100
# 35/35 [==============================] - 82s 2s/step - loss: 3.9160e-04 - val_loss: 0.0160
# Epoch 90/100
# 35/35 [==============================] - 71s 2s/step - loss: 4.6300e-04 - val_loss: 0.0158
# Epoch 91/100
# 35/35 [==============================] - 74s 2s/step - loss: 4.9668e-04 - val_loss: 0.0158
# Epoch 92/100
# 35/35 [==============================] - 82s 2s/step - loss: 5.1418e-04 - val_loss: 0.0157
# Epoch 93/100
# 35/35 [==============================] - 73s 2s/step - loss: 5.4273e-04 - val_loss: 0.0154
# Epoch 94/100
# 35/35 [==============================] - 81s 2s/step - loss: 4.7933e-04 - val_loss: 0.0162
# Epoch 95/100
# 35/35 [==============================] - 78s 2s/step - loss: 3.9374e-04 - val_loss: 0.0157
# Epoch 96/100
# 35/35 [==============================] - 79s 2s/step - loss: 3.7387e-04 - val_loss: 0.0164
# Epoch 97/100
# 35/35 [==============================] - 78s 2s/step - loss: 4.3185e-04 - val_loss: 0.0162
# Epoch 98/100
# 35/35 [==============================] - 73s 2s/step - loss: 4.5984e-04 - val_loss: 0.0160
# Epoch 99/100
# 35/35 [==============================] - 70s 2s/step - loss: 4.7727e-04 - val_loss: 0.0163
# Epoch 100/100
# 35/35 [==============================] - 66s 2s/step - loss: 4.4967e-04 - val_loss: 0.0158

# %%
model.save('./models/object_detection.h5')
